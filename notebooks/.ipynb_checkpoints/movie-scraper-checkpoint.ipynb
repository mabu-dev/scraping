# %%
from bs4 import BeautifulSoup
import requests

# %%
series = 'http://o2tvseries.com/Madam-Secretary-8/index.html'
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36'}

# %%
def initSeasons(url, flag):
#    print('FLAG IS:', flag)
    page = requests.get(url, headers=headers)
    #print(page.text)
    seasons = BeautifulSoup(page.text, "lxml")
  #  print('seasons found')
    if flag == "None":
    #    print('NONE')
        episodes = [episode for episode in seasons.find_all('a')]
    else:
        episodes = [episode for episode in seasons.find_all('a') if flag in str(episode)]
      #  print('NOT NONE')
    episodes.reverse()
    return episodes

# %%
print('initSeasons: processing SEASONS')
seasons = initSeasons(series, 'Season')
for season in seasons:
    url = season.get('href')
    this_season = str(str(url).split('/')[4])
    print('processing ' + this_season + ' @ '+ str(url))
    episodes = initSeasons(url, 'Episode')
    for e in episodes:
        url = e.get('href')
        this_episode = str(url).split('/')[5]
        print('processing ' + this_episode) # + ' @ '+ str(url))
        formats = initSeasons(url, 'download')
        for f in formats:
            if 'HD' in str(f):
#                http://d10.o2tvseries.com/Madam%20Secretary/Season%2004/Madam%20Secretary%20-%20S04E01%20HD%20(TvShows4Mobile.Com).mp4
  #              http://d2.o2tvseries.com/Madam%20Secretary/Season%2004/Madam%20Secretary%20-%20S04E02%20HD%20(TvShows4Mobile.Com).mp4
                url = f.get('href')
                print('..down link found @ ' + str(url))
                files = initSeasons(str(url)+'/index.html', 'None')
                print('return')
                for m in files:
                    print(m.get('href'))
# Out:
# initSeasons: processing SEASONS
# processing Season-04 @ http://o2tvseries.com/Madam-Secretary-8/Season-04/index.html
# processing Episode-01
# ..down link found @ http://o2tvseries.com/download/38255
# return
# http://o2tvseries.com/y
# http://o2tvseries.com/v
# http://o2tvseries.com/s
# http://o2tvseries.com/p
# http://o2tvseries.com/m
# http://o2tvseries.com/j
# http://o2tvseries.com/g
# http://o2tvseries.com/d
# http://o2tvseries.com/a
# http://o2tvseries.com/search/recently_added
# http://www.facebook.com/o2tvseries.official
# http://o2tvseries.com/
# http://o2tvseries.com/search/genre
# http://o2tvseries.com/search/list_all_tv_series
# http://o2tvseries.com/
# processing Episode-02
# ..down link found @ http://o2tvseries.com/download/38495
# return
# http://o2tvseries.com/y
# http://o2tvseries.com/v
# http://o2tvseries.com/s
# http://o2tvseries.com/p
# http://o2tvseries.com/m
# http://o2tvseries.com/j
# http://o2tvseries.com/g
# http://o2tvseries.com/d
# http://o2tvseries.com/a
# http://o2tvseries.com/search/recently_added
# http://www.facebook.com/o2tvseries.official
# http://o2tvseries.com/
# http://o2tvseries.com/search/genre
# http://o2tvseries.com/search/list_all_tv_series
# http://o2tvseries.com/
# processing Episode-03
# ..down link found @ http://o2tvseries.com/download/38800
# return
# http://o2tvseries.com/y
# http://o2tvseries.com/v
# http://o2tvseries.com/s
# http://o2tvseries.com/p
# http://o2tvseries.com/m
# http://o2tvseries.com/j
# http://o2tvseries.com/g
# http://o2tvseries.com/d
# http://o2tvseries.com/a
# http://o2tvseries.com/search/recently_added
# http://www.facebook.com/o2tvseries.official
# http://o2tvseries.com/
# http://o2tvseries.com/search/genre
# http://o2tvseries.com/search/list_all_tv_series
# http://o2tvseries.com/
# processing Episode-04
# ..down link found @ http://o2tvseries.com/download/39055
# return
# http://o2tvseries.com/y
# http://o2tvseries.com/v
# http://o2tvseries.com/s
# http://o2tvseries.com/p
# http://o2tvseries.com/m
# http://o2tvseries.com/j
# http://o2tvseries.com/g
# http://o2tvseries.com/d
# http://o2tvseries.com/a
# http://o2tvseries.com/search/recently_added
# http://www.facebook.com/o2tvseries.official
# http://o2tvseries.com/
# http://o2tvseries.com/search/genre
# http://o2tvseries.com/search/list_all_tv_series
# http://o2tvseries.com/
# processing Episode-05
# ..down link found @ http://o2tvseries.com/download/39687
# return
# http://o2tvseries.com/y
# http://o2tvseries.com/v
# http://o2tvseries.com/s
# http://o2tvseries.com/p
# http://o2tvseries.com/m
# http://o2tvseries.com/j
# http://o2tvseries.com/g
# http://o2tvseries.com/d
# http://o2tvseries.com/a
# http://o2tvseries.com/search/recently_added
# http://www.facebook.com/o2tvseries.official
# http://o2tvseries.com/
# http://o2tvseries.com/search/genre
# http://o2tvseries.com/search/list_all_tv_series
# http://o2tvseries.com/
# processing Episode-06
# ..down link found @ http://o2tvseries.com/download/39958
# return
# http://o2tvseries.com/y
# http://o2tvseries.com/v
# http://o2tvseries.com/s
# http://o2tvseries.com/p
# http://o2tvseries.com/m
# http://o2tvseries.com/j
# http://o2tvseries.com/g
# http://o2tvseries.com/d
# http://o2tvseries.com/a
# http://o2tvseries.com/search/recently_added
# http://www.facebook.com/o2tvseries.official
# http://o2tvseries.com/
# http://o2tvseries.com/search/genre
# http://o2tvseries.com/search/list_all_tv_series
# http://o2tvseries.com/
# processing Episode-07
# ..down link found @ http://o2tvseries.com/download/40306
# return
# http://o2tvseries.com/y
# http://o2tvseries.com/v
# http://o2tvseries.com/s
# http://o2tvseries.com/p
# http://o2tvseries.com/m
# http://o2tvseries.com/j
# http://o2tvseries.com/g
# http://o2tvseries.com/d
# http://o2tvseries.com/a
# http://o2tvseries.com/search/recently_added
# http://www.facebook.com/o2tvseries.official
# http://o2tvseries.com/
# http://o2tvseries.com/search/genre
# http://o2tvseries.com/search/list_all_tv_series
# http://o2tvseries.com/
# processing Episode-08
# ..down link found @ http://o2tvseries.com/download/40469
# return
# http://o2tvseries.com/y
# http://o2tvseries.com/v
# http://o2tvseries.com/s
# http://o2tvseries.com/p
# http://o2tvseries.com/m
# http://o2tvseries.com/j
# http://o2tvseries.com/g
# http://o2tvseries.com/d
# http://o2tvseries.com/a
# http://o2tvseries.com/search/recently_added
# http://www.facebook.com/o2tvseries.official
# http://o2tvseries.com/
# http://o2tvseries.com/search/genre
# http://o2tvseries.com/search/list_all_tv_series
# http://o2tvseries.com/
